# %%
import torch
import torchvision
import matplotlib.pyplot as plt

# %%
def show_images(datset, num_samples=20, cols=4):
    """ Plots some samples from the dataset """
    plt.figure(figsize=(15,15)) 
    for i, img in enumerate(data):
        if i == num_samples:
            break
        plt.subplot(int(num_samples/cols) + 1, cols, i + 1)
        plt.imshow(img[0])

data = torchvision.datasets.Caltech101(root='.', download=True)
# Out:
# 131740031it [00:18, 7191363.37it/s]
# Extracting ./caltech101/101_ObjectCategories.tar.gz to ./caltech101
# 14028800it [00:01, 10557105.57it/s]
# Extracting ./caltech101/Annotations.tar to ./caltech101

# %%
show_images(data)
